# %% [markdown]
# <a href="https://colab.research.google.com/github/Giffah/Prodigy_ML_01/blob/main/Prodigy_ML_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import  mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df =pd.read_csv('/content/train.csv', usecols= ['GrLivArea','BedroomAbvGr','FullBath','SalePrice'])

test_data =pd.read_csv('/content/test.csv', usecols= ['GrLivArea','BedroomAbvGr','FullBath'])
Id =pd.read_csv('/content/test.csv', usecols= ['Id'])

Id
# Out:
#         Id
# 0     1461
# 1     1462
# 2     1463
# 3     1464
# 4     1465
# ...    ...
# 1454  2915
# 1455  2916
# 1456  2917
# 1457  2918
# 1458  2919
#
# [1459 rows x 1 columns]

# %%
x=df.drop('SalePrice',axis=1).values
y=df['SalePrice'].values

# %%
Scaler=StandardScaler()
x=Scaler.fit_transform(x)
test_data=Scaler.fit_transform(test_data)

# %%
over = RandomOverSampler()
x,y = over.fit_resample(x,y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred =model.predict(x_test)

# %%
print(f'The mean squared error is {mean_squared_error(y_pred,y_test)}')
print(f'The R2 score is {r2_score(y_pred,y_test)}')
# Out:
# The mean squared error is 3050143510.4255795
# The R2 score is 0.5286545689360571

# %%
pred_data =model.predict(test_data)

pred_data=np.round(pred_data,1)
pred_data
# Out:
# array([112947.1, 141774.3, 218596.5, ...,  90035.5,  88013.7, 274154.2])

# %%
data = np.hstack((Id,np.reshape(pred_data,(-1,1))))
df_new = pd.DataFrame(data, columns=['Id', 'SalePrice'])

# %%
df_new
# Out:
#           Id  SalePrice
# 0     1461.0   112947.1
# 1     1462.0   141774.3
# 2     1463.0   218596.5
# 3     1464.0   214852.7
# 4     1465.0   202348.3
# ...      ...        ...
# 1454  2915.0   106283.3
# 1455  2916.0   106283.3
# 1456  2917.0    90035.5
# 1457  2918.0    88013.7
# 1458  2919.0   274154.2
#
# [1459 rows x 2 columns]

# %%
df_new.to_csv('Prodigy_ML_01_sub.csv', index=False)
